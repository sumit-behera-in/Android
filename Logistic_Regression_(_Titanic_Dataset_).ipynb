# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitbehera1508/Android/blob/main/Logistic_Regression_(_Titanic_Dataset_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# %%
# !kaggle datasets download -d brendan45774/test-file
# Out:
# Dataset URL: https://www.kaggle.com/datasets/brendan45774/test-file
# License(s): CC0-1.0
# test-file.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip test-file.zip
# Out:
# Archive:  test-file.zip
# replace tested.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: tested.csv

# %%
import pandas as pd
df = pd.read_csv('tested.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  34.5   7.8292
# 1         1       3  female  47.0   7.0000
# 2         0       2    male  62.0   9.6875
# 3         0       3    male  27.0   8.6625
# 4         1       3  female  22.0  12.2875

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   Fare      417 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 16.5+ KB

# %%
df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df.Fare.fillna(df.Fare.mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       418 non-null    float64
#  4   Fare      418 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 16.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le_Sex = LabelEncoder()

df['Sex'] = le_Sex.fit_transform(df['Sex'])
df.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    1  34.5   7.8292
# 1         1       3    0  47.0   7.0000
# 2         0       2    1  62.0   9.6875
# 3         0       3    1  27.0   8.6625
# 4         1       3    0  22.0  12.2875

# %%
x= df.drop(['Survived'],axis='columns')
y=df.Survived

# %%
x
# Out:
#      Pclass  Sex       Age      Fare
# 0         3    1  34.50000    7.8292
# 1         3    0  47.00000    7.0000
# 2         2    1  62.00000    9.6875
# 3         3    1  27.00000    8.6625
# 4         3    0  22.00000   12.2875
# ..      ...  ...       ...       ...
# 413       3    1  30.27259    8.0500
# 414       1    0  39.00000  108.9000
# 415       3    1  38.50000    7.2500
# 416       3    1  30.27259    8.0500
# 417       3    1  30.27259   22.3583
#
# [418 rows x 4 columns]

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)*100
# Out:
# 100.0

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[53,  0],
#        [ 0, 31]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        53
#            1       1.00      1.00      1.00        31
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
model.predict_proba(x_test)
# Out:
# array([[0.96801123, 0.03198877],
#        [0.96672922, 0.03327078],
#        [0.97154132, 0.02845868],
#        [0.97389275, 0.02610725],
#        [0.05421668, 0.94578332],
#        [0.03884149, 0.96115851],
#        [0.06270117, 0.93729883],
#        [0.04166039, 0.95833961],
#        [0.04997983, 0.95002017],
#        [0.96867829, 0.03132171],
#        [0.9576896 , 0.0423104 ],
#        [0.96859767, 0.03140233],
#        [0.97318125, 0.02681875],
#        [0.97486731, 0.02513269],
#        [0.97172899, 0.02827101],
#        [0.0543845 , 0.9456155 ],
#        [0.06226172, 0.93773828],
#        [0.96918146, 0.03081854],
#        [0.03423745, 0.96576255],
#        [0.06011754, 0.93988246],
#        [0.97408909, 0.02591091],
#        [0.04589583, 0.95410417],
#        [0.96991929, 0.03008071],
#        [0.06359492, 0.93640508],
#        [0.95820397, 0.04179603],
#        [0.05924982, 0.94075018],
#        [0.9725599 , 0.0274401 ],
#        [0.96479932, 0.03520068],
# ...
